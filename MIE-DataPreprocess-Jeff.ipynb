# %%
from pyspark.sql import Row
from pyspark import SparkConf, SparkContext, SQLContext
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType
from pyspark.sql.types import FloatType
from pyspark.sql.types import DoubleType
from pyspark.sql.functions import udf
from pyspark.sql import functions as F 
from pyspark.sql.functions import explode, col, udf, mean as _mean, stddev as _stddev, log, log10, isnan, when, count
from pyspark.sql.types import StructType
from pyspark.sql.types import StructField
from pyspark.sql.functions import lit
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location = "/FileStore/tables/train_features.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
rows = df.count()
print('Rows: ', rows)

# Check for number of duplicate rows
duplicates = df.groupBy(df.columns).count().where(F.col('count') > 1).select(F.sum('count').alias('Duplicate Row Count')).collect()

# Check for number of rows with for missing value columns
dropped_na_df = df.dropna(how="any", thresh=None, subset=None)
num_missing_rows = rows - dropped_na_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Rows:  23814
# </div>

# %%
num_duplicate_rows = 0 if duplicates[0].__getitem__("Duplicate Row Count")==None else duplicates[0].__getitem__("Duplicate Row Count")

print('Number of duplicate rows: ', num_duplicate_rows)
print('Number of rows with missing value: ', num_missing_rows)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of duplicate row:  0
# Number of rows with missing value:  0
# </div>

# %%
# Convert data types from string to doubles. There are 875 columns, 3 of them are categorical data: id, cp_type and cp_dose
# NOTE: This takes several minutes
categorical_cols = ["sig_id", "cp_type", "cp_dose"]
numeric_cols = [col for col in df.columns if col not in categorical_cols]

for col_name in numeric_cols:
  df = df.withColumn(col_name, col(col_name).cast(DoubleType()))
    
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [(&#39;sig_id&#39;, &#39;string&#39;),
#  (&#39;cp_type&#39;, &#39;string&#39;),
#  (&#39;cp_time&#39;, &#39;double&#39;),
#  (&#39;cp_dose&#39;, &#39;string&#39;),
#  (&#39;g-0&#39;, &#39;double&#39;),
#  (&#39;g-1&#39;, &#39;double&#39;),
#  (&#39;g-2&#39;, &#39;double&#39;),
#  (&#39;g-3&#39;, &#39;double&#39;),
#  (&#39;g-4&#39;, &#39;double&#39;),
#  (&#39;g-5&#39;, &#39;double&#39;),
#  (&#39;g-6&#39;, &#39;double&#39;),
#  (&#39;g-7&#39;, &#39;double&#39;),
#  (&#39;g-8&#39;, &#39;double&#39;),
#  (&#39;g-9&#39;, &#39;double&#39;),
#  (&#39;g-10&#39;, &#39;double&#39;),
#  (&#39;g-11&#39;, &#39;double&#39;),
# ...

# %%
# Standardize each numeric column
from pyspark.ml.feature import VectorAssembler, StandardScaler

# Assemble all numeric features into one column before passing it to StandardScalar
# Learn more at - https://spark.apache.org/docs/latest/ml-features#standardscaler
vector_assembler = VectorAssembler(inputCols=numeric_cols, outputCol="std_numeric")
assembled_df = vector_assembler.transform(df)

std_scaler = StandardScaler(inputCol="std_numeric", outputCol="scaledFeatures")
scaler_model = std_scaler.fit(assembled_df)
scaled_df = scaler_model.transform(assembled_df)

# The scaled features are grouped together in the scaledFeatures column
scaled_df.select('scaledFeatures').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#       scaledFeatures|
# +--------------------+
# [1.23693443288930...|
# [3.71080329866792...|
# [2.47386886577861...|
# [2.47386886577861...|
# [3.71080329866792...|
# [1.23693443288930...|
# [1.23693443288930...|
# [2.47386886577861...|
# [2.47386886577861...|
# [2.47386886577861...|
# [3.71080329866792...|
# [2.47386886577861...|
# [2.47386886577861...|
# [2.47386886577861...|
# [3.71080329866792...|
# [2.47386886577861...|
# [2.47386886577861...|
# [1.23693443288930...|
# [3.71080329866792...|
# [2.47386886577861...|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
scaled_df.select('scaledFeatures').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#       scaledFeatures|
# +--------------------+
# [1.23693443288930...|
# [3.71080329866792...|
# [2.47386886577861...|
# [2.47386886577861...|
# [3.71080329866792...|
# [1.23693443288930...|
# [1.23693443288930...|
# [2.47386886577861...|
# [2.47386886577861...|
# [2.47386886577861...|
# [3.71080329866792...|
# [2.47386886577861...|
# [2.47386886577861...|
# [2.47386886577861...|
# [3.71080329866792...|
# [2.47386886577861...|
# [2.47386886577861...|
# [1.23693443288930...|
# [3.71080329866792...|
# [2.47386886577861...|
# +--------------------+
# only showing top 20 rows
#
# </div>
